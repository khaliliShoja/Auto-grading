# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Feature-Extraction" data-toc-modified-id="Feature-Extraction-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Feature Extraction</a></span></li><li><span><a href="#Results" data-toc-modified-id="Results-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Results</a></span></li></ul></div>

# %% [markdown]
# # Feature Extraction
#
#
# As a first step, I will perform feature extraction. The results of this step will be saved as a dataframe and will be used in the next step.

# %%
import pandas as pd
import re
import numpy as np
import scipy as sp
from textblob import TextBlob
from textblob import Word
import language_check
import enchant
import sys
sys.path.append("C://Users//mohammad//Desktop//khalili")
import Preprocess as pss

# %%
df = pd.read_csv("C://Users//mohammad//Desktop//khalili//challenge.csv" , encoding = "latin1")
df.head()
# Out:
#    essay_id  essay_set                                              essay  \
# 0         1          1  Dear local newspaper, I think effects computer...
# 1         2          1  Dear @CAPS1 @CAPS2, I believe that using compu...
# 2         3          1  Dear, @CAPS1 @CAPS2 @CAPS3 More and more peopl...
# 3         4          1  Dear Local Newspaper, @CAPS1 I have found that...
# 4         5          1  Dear @LOCATION1, I know having computers has a...
#
#    rater1_domain1  rater2_domain1  domain1_score
# 0             4.0             4.0            8.0
# 1             5.0             4.0            9.0
# 2             4.0             3.0            7.0
# 3             5.0             5.0           10.0
# 4             4.0             4.0            8.0

# %% [markdown]
# I have written a class to extarct the features. The features include number of words, number of sentences, average length of sentences, number of long words, the polarity of the essay, number of nouns, number of verbs, number of adverbs, number of adjectives, number of grammer mistakes and number of spelling mistakes. The code of this class can be find in a file called "Preprocess.py"

# %%
prepro = pss.PreprocessData()

# %%
prepro.processData(df)

# %% [markdown]
# # Results

# %%
df.head()
# Out:
#    essay_id  essay_set                                              essay  \
# 0         1          1  Dear local newspaper, I think effects computer...
# 1         2          1  Dear @CAPS1 @CAPS2, I believe that using compu...
# 2         3          1  Dear, @CAPS1 @CAPS2 @CAPS3 More and more peopl...
# 3         4          1  Dear Local Newspaper, @CAPS1 I have found that...
# 4         5          1  Dear @LOCATION1, I know having computers has a...
#
#    rater1_domain1  rater2_domain1  domain1_score  *_# of words_*  \
# 0             4.0             4.0            8.0           343.0
# 1             5.0             4.0            9.0           422.0
# 2             4.0             3.0            7.0           283.0
# 3             5.0             5.0           10.0           527.0
# 4             4.0             4.0            8.0           470.0
#
#    *_# of sentences_*  *_Average lenght of sentences_*  *_# of large words_*  \
# ...

# %%
df.tail()
# Out:
#        essay_id  essay_set                                              essay  \
# 12973     21626          8   In most stories mothers and daughters are eit...
# 12974     21628          8   I never understood the meaning laughter is th...
# 12975     21629          8  When you laugh, is @CAPS5 out of habit, or is ...
# 12976     21630          8                                 Trippin' on fen...
# 12977     21633          8   Many people believe that laughter can improve...
#
#        rater1_domain1  rater2_domain1  domain1_score  *_# of words_*  \
# 12973            17.0            18.0           35.0           863.0
# 12974            15.0            17.0           32.0           556.0
# 12975            20.0            26.0           40.0           827.0
# 12976            20.0            20.0           40.0           576.0
# 12977            20.0            20.0           40.0           475.0
#
#        *_# of sentences_*  *_Average lenght of sentences_*  \
# ...

# %%
df.to_csv("C://Users//zzare//Desktop//khalili//data.csv")

# %% [markdown]
# Next step is in "Main_1.ipynb"
